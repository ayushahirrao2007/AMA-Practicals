# %%
# Program to implement K-Means Clustering Algorithm

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Create dataset
data = {
    'X': [1, 2, 3, 2, 3, 4, 8, 9, 10, 9, 10, 11, 15, 16, 17, 16, 17, 18],
    'Y': [1, 2, 1, 3, 2, 3, 8, 9, 8, 10, 9, 10, 15, 16, 15, 17, 16, 17]
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)

# Create K-Means model
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)

# Train the model
kmeans.fit(df)

# Add cluster labels to DataFrame
df['Cluster'] = kmeans.labels_

print("\nClustered Dataset:")
print(df)

# Display cluster centers
print("\nCluster Centers:")
print(kmeans.cluster_centers_)

# Display graph
plt.figure(figsize=(8, 6))

plt.scatter(
    df['X'],
    df['Y'],
    c=df['Cluster'],
    s=100
)

plt.scatter(
    kmeans.cluster_centers_[:, 0],
    kmeans.cluster_centers_[:, 1],
    marker='X',
    s=200
)

plt.xlabel("X")
plt.ylabel("Y")
plt.title("K-Means Clustering")
plt.show()
# Out:
# Dataset:
#      X   Y
# 0    1   1
# 1    2   2
# 2    3   1
# 3    2   3
# 4    3   2
# 5    4   3
# 6    8   8
# 7    9   9
# 8   10   8
# 9    9  10
# 10  10   9
# 11  11  10
# 12  15  15
# 13  16  16
# 14  17  15
# 15  16  17
# 16  17  16
# 17  18  17
#
# Clustered Dataset:
#      X   Y  Cluster
# 0    1   1        2
# 1    2   2        2
# 2    3   1        2
# 3    2   3        2
# 4    3   2        2
# 5    4   3        2
# 6    8   8        0
# 7    9   9        0
# 8   10   8        0
# 9    9  10        0
# 10  10   9        0
# 11  11  10        0
# 12  15  15        1
# 13  16  16        1
# 14  17  15        1
# 15  16  17        1
# 16  17  16        1
# 17  18  17        1
#
# Cluster Centers:
# [[ 9.5  9. ]
#  [16.5 16. ]
#  [ 2.5  2. ]]
